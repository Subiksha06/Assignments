# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'C:\Users\DELL\Downloads\medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(15)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# 13   56  female  39.820         0     no  southeast  11090.71780
# 14   27    male  42.130         0    yes  southeast  39611.75770

# %%
df.tail(16)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1322   62    male  38.830         0     no  southeast  12981.34570
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1327   51    male  30.030         1     no  southeast   9377.90470
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# There are no null values in this dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
for i in df.columns:
    print(df[i].unique())
    print('\n')
    print(df[i].nunique())
    print('\n')
# Out:
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
#
# 47
#
#
# ['female' 'male']
#
#
# 2
#
#
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
#  38.28  19.95  19.3   31.6   25.46  30.115 29.92  27.5   28.4   30.875
#  27.94  35.09  29.7   35.72  32.205 28.595 49.06  27.17  23.37  37.1
#  23.75  28.975 31.35  33.915 28.785 28.3   37.4   17.765 34.7   26.505
#  22.04  35.9   25.555 28.05  25.175 31.9   36.    32.49  25.3   29.735
#  38.83  30.495 37.73  37.43  24.13  37.145 39.52  24.42  27.83  36.85
#  39.6   29.8   29.64  28.215 37.    33.155 18.905 41.47  30.3   15.96
#  33.345 37.7   27.835 29.2   26.41  30.69  41.895 30.9   32.2   32.11
#  31.57  26.2   30.59  32.8   18.05  39.33  32.23  24.035 36.08  22.3
#  26.4   31.8   26.73  23.1   23.21  33.7   33.25  24.64  33.88  38.06
#  41.91  31.635 36.195 17.8   24.51  22.22  38.39  29.07  22.135 26.8
#  30.02  35.86  20.9   17.29  34.21  25.365 40.15  24.415 25.2   26.84
#  24.32  42.35  19.8   32.395 30.2   29.37  34.2   27.455 27.55  20.615
#  24.3   31.79  21.56  28.12  40.565 27.645 31.2   26.62  48.07  36.765
#  33.4   45.54  28.82  22.99  27.7   25.41  34.39  22.61  37.51  38.
#  33.33  34.865 33.06  35.97  31.4   25.27  40.945 34.105 36.48  33.8
#  36.7   36.385 34.5   32.3   27.6   29.26  35.75  23.18  25.6   35.245
#  43.89  20.79  30.5   21.7   21.89  24.985 32.015 30.4   21.09  22.23
#  32.9   24.89  31.46  17.955 30.685 43.34  39.05  30.21  31.445 19.855
#  31.02  38.17  20.6   47.52  20.4   38.38  24.31  23.6   21.12  30.03
#  17.48  20.235 17.195 23.9   35.15  35.64  22.6   39.16  27.265 29.165
#  16.815 33.1   26.9   33.11  31.73  46.75  29.45  32.68  33.5   43.01
#  36.52  26.695 25.65  29.6   38.6   23.4   46.53  30.14  30.    38.095
#  28.38  28.7   33.82  24.09  32.67  25.1   32.56  41.325 39.5   34.3
#  31.065 21.47  25.08  43.4   25.7   27.93  39.2   26.03  30.25  28.93
#  35.7   35.31  31.    44.22  26.07  25.8   39.425 40.48  38.9   47.41
#  35.435 46.7   46.2   21.4   23.8   44.77  32.12  29.1   37.29  43.12
#  36.86  34.295 23.465 45.43  23.65  20.7   28.27  35.91  29.    19.57
#  31.13  21.85  40.26  33.725 29.48  32.6   37.525 23.655 37.8   19.
#  21.3   33.535 42.46  38.95  36.1   29.3   39.7   38.19  42.4   34.96
#  42.68  31.54  29.81  21.375 40.81  17.4   20.3   18.5   26.125 41.69
#  24.1   36.2   40.185 39.27  34.87  44.745 29.545 23.54  40.47  40.66
#  36.6   35.4   27.075 28.405 21.755 40.28  30.1   32.1   23.7   35.5
#  29.15  27.    37.905 22.77  22.8   34.58  27.1   19.475 26.7   34.32
#  24.4   41.14  22.515 41.8   26.18  42.24  26.51  35.815 41.42  36.575
#  42.94  21.01  24.225 17.67  31.5   31.1   32.78  32.45  50.38  47.6
#  25.4   29.9   43.7   24.86  28.8   29.5   29.04  38.94  44.    20.045
#  40.92  35.1   29.355 32.585 32.34  39.8   24.605 33.99  28.2   25.
#  33.2   23.2   20.1   32.5   37.18  46.09  39.93  35.8   31.255 18.335
#  42.9   26.79  39.615 25.9   25.745 28.16  23.56  40.5   35.42  39.995
#  34.675 20.52  23.275 36.29  32.7   19.19  20.13  23.32  45.32  34.6
#  18.715 21.565 23.    37.07  52.58  42.655 21.66  32.    18.3   47.74
#  22.1   19.095 31.24  29.925 20.35  25.85  42.75  18.6   23.87  45.9
#  21.5   30.305 44.88  41.1   40.37  28.49  33.55  40.375 27.28  17.86
#  33.3   39.14  21.945 24.97  23.94  34.485 21.8   23.3   36.96  21.28
#  29.4   27.3   37.9   37.715 23.76  25.52  27.61  27.06  39.4   34.9
#  22.    30.36  27.8   53.13  39.71  32.87  44.7   30.97 ]
#
#
# 548
#
#
# [0 1 3 2 5 4]
#
#
# 6
#
#
# ['yes' 'no']
#
#
# 2
#
#
# ['southwest' 'southeast' 'northwest' 'northeast']
#
#
# 4
#
#
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]
#
#
# 1337

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %%
df['charges'].value_counts()
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %% [markdown]
# # Description of dataset

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Visualisation of dataset

# %%
sns.histplot(x='age',data=df,bins=10)
print(df['age'].value_counts())
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
sns.countplot(x='sex',data=df)
print(df['sex'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.histplot(x='bmi',data=df)
print(df['bmi'].value_counts())
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %%
sns.histplot(x='children',data=df)
print(df['children'].value_counts())
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
sns.countplot(x='smoker',data=df)
print(df['smoker'].value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
sns.countplot(x='region',data=df)
print(df['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.violinplot(x='charges',data=df)
print(df['charges'].value_counts())
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %% [markdown]
# # Bivariant analysis

# %%
sns.boxplot(y="age",x="sex",data=df,hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.histplot(x='charges',data=df)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.scatterplot(x="bmi",data=df,y="age")
# Out:
# <Axes: xlabel='bmi', ylabel='age'>

# %%
sns.scatterplot(x="region",data=df,y="charges")
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.catplot(x="region",data=df,y="charges", hue='smoker')

# %%
sns.catplot(x="sex",data=df,y="children", hue='smoker', kind='bar')

# %%
sns.scatterplot(x="age",data=df,y="charges")
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
plt.plot(df['charges'], data=df)

# %%
sns.pairplot(df,hue="smoker", palette = "Dark2")
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=13:
        plt.subplot(5,4,p)
        sns.boxplot(df[i], palette='Set2_r')
        plt.xlabel(i)
        
    p+=1
    
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=13:
        plt.subplot(5,4,p)
        sns.histplot(df[i], bins=10, kde=True, palette='Set2_r')
        plt.xlabel(i)
        
    p+=1
    
plt.show()

# %% [markdown]
# # checking for skewness

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#from scipy.stats import boxcox 

df["children"] = np.cbrt(df["children"])
df["charges"] = np.cbrt(df["charges"])

# %%
df.skew()
# Out:
# age         0.055673
# bmi         0.284047
# children   -0.097116
# charges     0.515183
# dtype: float64

# %%
sns.histplot(df['charges'])
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
    
df
# Out:
#       age  sex     bmi  children  smoker  region    charges
# 0      19  0.0  27.900   0.00000     1.0     3.0  25.654666
# 1      18  1.0  33.770   1.00000     0.0     2.0  11.994331
# 2      28  1.0  33.000   1.44225     0.0     2.0  16.447599
# 3      33  1.0  22.705   0.00000     0.0     1.0  28.013799
# 4      32  1.0  28.880   0.00000     0.0     1.0  15.695891
# ...   ...  ...     ...       ...     ...     ...        ...
# 1333   50  1.0  30.970   1.44225     0.0     1.0  21.967271
# 1334   18  0.0  31.920   0.00000     0.0     0.0  13.017690
# 1335   18  0.0  36.850   0.00000     0.0     2.0  11.768318
# 1336   21  0.0  25.800   0.00000     0.0     3.0  12.615872
# 1337   61  0.0  29.070   0.00000     1.0     1.0  30.773007
#
# [1338 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex         float64
# bmi         float64
# children    float64
# smoker      float64
# region      float64
# charges     float64
# dtype: object

# %% [markdown]
# # checking correlation

# %%
cor=df.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.048919 -0.025019  0.002127  0.451354
# sex      -0.020856  1.000000  0.046371  0.016183  0.076185  0.004588  0.027560
# bmi       0.109272  0.046371  1.000000  0.016515  0.003750  0.157566  0.156375
# children  0.048919  0.016183  0.016515  1.000000  0.011829  0.014133  0.128511
# smoker   -0.025019  0.076185  0.003750  0.011829  1.000000 -0.002181  0.732564
# region    0.002127  0.004588  0.157566  0.014133 -0.002181  1.000000 -0.029807
# charges   0.451354  0.027560  0.156375  0.128511  0.732564 -0.029807  1.000000

# %%
sns.heatmap(cor, annot=True, fmt = ".1g")
# Out:
# <Axes: >

# %%
cor['charges'].sort_values(ascending = False)
# Out:
# charges     1.000000
# smoker      0.732564
# age         0.451354
# bmi         0.156375
# children    0.128511
# sex         0.027560
# region     -0.029807
# Name: charges, dtype: float64

# %%
cor['charges'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Seperating feautures and model

# %%
x=df.drop("charges", axis=1)
y=df['charges']

# %%
x.shape
# Out:
# (1338, 6)

# %%
y.shape
# Out:
# (1338,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.438764 -1.010519 -0.453320 -1.117604  1.970587  1.343905
# 1    -1.509965  0.989591  0.509621  0.502009 -0.507463  0.438495
# 2    -0.797954  0.989591  0.383307  1.218282 -0.507463  0.438495
# 3    -0.441948  0.989591 -1.305531 -1.117604 -0.507463 -0.466915
# 4    -0.513149  0.989591 -0.292556 -1.117604 -0.507463 -0.466915
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.218282 -0.507463 -0.466915
# 1334 -1.509965 -1.010519  0.206139 -1.117604 -0.507463 -1.372326
# 1335 -1.509965 -1.010519  1.014878 -1.117604 -0.507463  0.438495
# 1336 -1.296362 -1.010519 -0.797813 -1.117604 -0.507463  1.343905
# 1337  1.551686 -1.010519 -0.261388 -1.117604  1.970587 -0.466915
#
# [1338 rows x 6 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#    VIF values  Features
# 0    1.015956       age
# 1    1.008844       sex
# 2    1.040656       bmi
# 3    1.003101  children
# 4    1.006551    smoker
# 5    1.025881    region

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score 
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.linear_model import LinearRegression

# %%
max_acc = 0
rs = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = i)
    LR  = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    accuracy = r2_score(y_test, pred)
    if accuracy>max_acc:
        max_acc = accuracy
        rs = i
        
print("Best accuracy is", max_acc,"at random state", rs)
# Out:
# Best accuracy is 0.8273389787575155 at random state 112

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = rs)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.neighbors import KNeighborsRegressor as KNN 
from sklearn.linear_model import Lasso, Ridge

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train= LR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_LR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_LR))
print('mean_squared_error is', mean_squared_error(y_test, pred_LR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# r2_score is  0.8273389787575155
# r2_score of training is  0.7563580526598115
# mean_absolute_error is 1.955704575028898
# mean_squared_error is 8.040012315330728
# root_mean_squared_error is 2.8354915473918676

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train= RFR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_RFR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_RFR))
print('mean_squared_error is', mean_squared_error(y_test, pred_RFR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# r2_score is  0.8684962587680156
# r2_score of training is  0.9677506030194178
# mean_absolute_error is 1.3535532564748536
# mean_squared_error is 6.123511209471899
# root_mean_squared_error is 2.4745729347650878

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
knn=KNN()
knn.fit(x_train, y_train)
pred_knn = knn.predict(x_test)
pred_train= knn.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_knn))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_knn))
print('mean_squared_error is', mean_squared_error(y_test, pred_knn))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# r2_score is  0.8418102053383023
# r2_score of training is  0.8418245267283241
# mean_absolute_error is 1.7799474212471822
# mean_squared_error is 7.366155302959259
# root_mean_squared_error is 2.7140661935478394

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
lasso=Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train= lasso.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_lasso))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_lasso))
print('mean_squared_error is', mean_squared_error(y_test, pred_lasso))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# r2_score is  0.7427808951621528
# r2_score of training is  0.6810574794633321
# mean_absolute_error is 2.633779121307018
# mean_squared_error is 11.97748487616254
# root_mean_squared_error is 3.4608503111464586

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
ridge=Ridge()
ridge.fit(x_train, y_train)
pred_ridge = ridge.predict(x_test)
pred_train= ridge.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_ridge))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_ridge))
print('mean_squared_error is', mean_squared_error(y_test, pred_ridge))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_ridge)))
# Out:
# r2_score is  0.8273092152397116
# r2_score of training is  0.7563570855369546
# mean_absolute_error is 1.9574793386647902
# mean_squared_error is 8.041398262477164
# root_mean_squared_error is 2.835735929609308

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(x_train, y_train)
pred_ETR = ETR.predict(x_test)
pred_train= ETR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_ETR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_ETR))
print('mean_squared_error is', mean_squared_error(y_test, pred_ETR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_ETR)))
# Out:
# r2_score is  0.8433484464180973
# r2_score of training is  0.9972645112683293
# mean_absolute_error is 1.3685550220493168
# mean_squared_error is 7.294526645046194
# root_mean_squared_error is 2.700838137513278

# %% [markdown]
# # cross val score

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_LR)-score.mean())
# Out:
# [0.800572   0.68881591 0.83527435 0.77207512 0.73680988]
# 0.7667094529772689
# Difference is 0.06062952578024661

# %%
score = cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_RFR)-score.mean())
# Out:
# [0.84462342 0.70295808 0.85858148 0.82270463 0.79328976]
# 0.8044314745739085
# Difference is 0.0640647841941071

# %%
score = cross_val_score(knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_knn)-score.mean())
# Out:
# [0.33645803 0.27905894 0.32681879 0.32398834 0.19744766]
# 0.2927543524144787
# Difference is 0.5490558529238236

# %%
score = cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_lasso)-score.mean())
# Out:
# [0.27307105 0.31044244 0.28365347 0.28300293 0.16565682]
# 0.26316534504639766
# Difference is 0.4796155501157552

# %%
score = cross_val_score(ridge,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_ridge)-score.mean())
# Out:
# [0.80039971 0.68932719 0.834797   0.77240797 0.73652923]
# 0.7666922196491767
# Difference is 0.060616995590534906

# %%
score = cross_val_score(ETR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_ETR)-score.mean())
# Out:
# [0.81237651 0.67202258 0.84735988 0.79254311 0.77692839]
# 0.7802460980371246
# Difference is 0.06310234838097262

# %% [markdown]
# By looking at the difference we can see that the ridge regression has the least difference and that is our best fitting model

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

param = {'alpha':[1, 0.05, 0.4, 2], 
              'fit_intercept':[True, False], 
              'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag', 'saga', 'lbfgs'], 
              'positive':[False, True], 
              'random_state':[1,4,10,20]    
}
gscv = GridSearchCV(Ridge(), param, cv=5)
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 20,
#  'solver': 'sag'}

# %%
Model=Ridge(alpha=2, fit_intercept=True, positive=False, random_state=20, solver='sag')

# %%
Model.fit(x_train, y_train)
pred = Model.predict(x_test)
print('r2_score is ',r2_score(y_test, pred))
print('mean_absolute_error is', mean_absolute_error(y_test, pred))
print('mean_squared_error is', mean_squared_error(y_test, pred))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# r2_score is  0.8272771006455399
# mean_absolute_error is 1.9593030661019077
# mean_squared_error is 8.042893688200838
# root_mean_squared_error is 2.8359995924190184

# %%
#saving model 
import pickle 
filename='medical_insurance.pkl'
pickle.dump(Model, open(filename,'wb'))

# %%
import pickle 
loaded_model = pickle.load(open('medical_insurance.pkl', 'rb'))
res = loaded_model.score(x_test, y_test)
print(res*100)
# Out:
# 82.72771006455399

# %%
final = pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=['predicted','original'])
final
# Out:
#                  0          1          2          3          4          5    \
# predicted  23.086096  20.351673  26.752370  33.797973  33.979851  20.562756
# original   22.300771  20.014208  32.591173  29.058028  28.831918  20.049609
#
#                  6          7          8          9    ...        392  \
# predicted  20.254597  30.232456  18.225442  14.867881  ...  19.888513
# original   20.208065  27.477553  17.384021  11.980144  ...  19.171778
#
#                 393        394        395        396        397        398  \
# predicted  26.71081  22.355992  18.993768  21.941339  19.665908  19.302182
# original   33.11311  23.760959  18.568571  21.447903  18.143278  17.374865
#
#                  399        400        401
# predicted  20.471028  14.307402  13.966931
# original   19.082468  13.891939  12.535078
#
# [2 rows x 402 columns]
